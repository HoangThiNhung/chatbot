# %%
from sqlalchemy.orm import sessionmaker
from models import *

Session = sessionmaker(bind=engine)

# %%
Base.metadata.create_all(engine)
# Out:
# 2018-01-31 17:14:09,180 INFO sqlalchemy.engine.base.Engine SELECT CAST('test plain returns' AS VARCHAR(60)) AS anon_1
# 2018-01-31 17:14:09,181 INFO sqlalchemy.engine.base.Engine ()
# 2018-01-31 17:14:09,182 INFO sqlalchemy.engine.base.Engine SELECT CAST('test unicode returns' AS VARCHAR(60)) AS anon_1
# 2018-01-31 17:14:09,183 INFO sqlalchemy.engine.base.Engine ()
# 2018-01-31 17:14:09,184 INFO sqlalchemy.engine.base.Engine PRAGMA table_info("menus")
# 2018-01-31 17:14:09,185 INFO sqlalchemy.engine.base.Engine ()
# 2018-01-31 17:14:09,187 INFO sqlalchemy.engine.base.Engine
# CREATE TABLE menus (
# 	id INTEGER NOT NULL,
# 	category VARCHAR,
# 	title VARCHAR,
# 	image VARCHAR,
# 	link VARCHAR,
# 	price FLOAT,
# 	n_gram_search_text VARCHAR,
# 	PRIMARY KEY (id)
# )
#
#
# 2018-01-31 17:14:09,188 INFO sqlalchemy.engine.base.Engine ()
# 2018-01-31 17:14:09,188 INFO sqlalchemy.engine.base.Engine COMMIT

# %%
import json

session = Session()
file_name = 'data/menu.json'
with open(file_name) as json_data:
    data = json.load(json_data)

for i in range(len(data)):
    menu = Menu(data[i]['category'], data[i]['title'], data[i]['image'], data[i]['link'], data[i]['price'])
    session.add(menu)
    session.commit()
# Out:
# 2018-01-31 17:14:10,661 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2018-01-31 17:14:10,665 INFO sqlalchemy.engine.base.Engine INSERT INTO menus (category, title, image, link, price, n_gram_search_text) VALUES (?, ?, ?, ?, ?, ?)
# 2018-01-31 17:14:10,668 INFO sqlalchemy.engine.base.Engine ('tráng miệng', 'Tào phớ', 'http://quananngon.com.vn/mediacenter/media/images/products/1428/1406/s330_330/tao-pho-1496723725.jpg', 'http://quananngon.com.vn/tao-pho-pd61389.html', 20000.0, 'tráng_miệng Tào_phớ')
# 2018-01-31 17:14:10,674 INFO sqlalchemy.engine.base.Engine COMMIT
# 2018-01-31 17:14:10,677 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2018-01-31 17:14:10,680 INFO sqlalchemy.engine.base.Engine INSERT INTO menus (category, title, image, link, price, n_gram_search_text) VALUES (?, ?, ?, ?, ?, ?)
# 2018-01-31 17:14:10,680 INFO sqlalchemy.engine.base.Engine ('tráng miệng', 'Chè sương sa hạt lựu', 'http://quananngon.com.vn/mediacenter/media/images/products/1428/1/s330_330/che-suong-sa-hat-luu-1495847292.jpg', 'http://quananngon.com.vn/che-suong-sa-hat-luu--test-pd60376.html', 28000.0, 'tráng_miệng Chè sương_sa hạt lựu')
# 2018-01-31 17:14:10,682 INFO sqlalchemy.engine.base.Engine COMMIT
# 2018-01-31 17:14:10,684 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2018-01-31 17:14:10,688 INFO sqlalchemy.engine.base.Engine INSERT INTO menus (category, title, image, link, price, n_gram_search_text) VALUES (?, ?, ?, ?, ?, ?)
# 2018-01-31 17:14:10,692 INFO sqlalchemy.engine.base.Engine ('món chính', 'Cá kho tộ', 'http://quananngon.com.vn/mediacenter/media/images/1428/products/1428/1406/s330_330/ca-kho-to-quan-an-ngon-1498546218.jpg', 'http://quananngon.com.vn/ca-kho-to-pd63424.html', 125000.0, 'món chính Cá kho_tộ')
# 2018-01-31 17:14:10,697 INFO sqlalchemy.engine.base.Engine COMMIT
# 2018-01-31 17:14:10,698 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2018-01-31 17:14:10,699 INFO sqlalchemy.engine.base.Engine INSERT INTO menus (category, title, image, link, price, n_gram_search_text) VALUES (?, ?, ?, ?, ?, ?)
# 2018-01-31 17:14:10,700 INFO sqlalchemy.engine.base.Engine ('món chính', 'Canh chua cá lóc', 'http://quananngon.com.vn/mediacenter/media/images/1428/products/1428/1406/s330_330/canh-chua-ca-loc-quan-an-ngon-1498546166.jpg', 'http://quananngon.com.vn/canh-chua-ca-loc-pd63425.html', 110000.0, 'món chính Canh chua cá_lóc')
# 2018-01-31 17:14:10,701 INFO sqlalchemy.engine.base.Engine COMMIT
# 2018-01-31 17:14:10,702 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2018-01-31 17:14:10,703 INFO sqlalchemy.engine.base.Engine INSERT INTO menus (category, title, image, link, price, n_gram_search_text) VALUES (?, ?, ?, ?, ?, ?)
# 2018-01-31 17:14:10,703 INFO sqlalchemy.engine.base.Engine ('tráng miệng', 'Chè chuối hấp nước dừa', 'http://quananngon.com.vn/mediacenter/media/images/1428/products/1428/1406/s330_330/che-chuoi-hap-cot-dua-quan-an-ngon-1498547198.jpg', 'http://quananngon.com.vn/che-chuoi-hap-nuoc-dua-pd62457.html', 24000.0, 'tráng_miệng Chè chuối hấp nước dừa')
# 2018-01-31 17:14:10,704 INFO sqlalchemy.engine.base.Engine COMMIT
# 2018-01-31 17:14:10,706 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2018-01-31 17:14:10,707 INFO sqlalchemy.engine.base.Engine INSERT INTO menus (category, title, image, link, price, n_gram_search_text) VALUES (?, ?, ?, ?, ?, ?)
# 2018-01-31 17:14:10,707 INFO sqlalchemy.engine.base.Engine ('tráng miệng', 'Chè hạt sen', 'http://quananngon.com.vn/mediacenter/media/images/products/1428/1406/s330_330/che-hat-sen-quan-an-ngon-1497433128.jpg', 'http://quananngon.com.vn/che-hat-sen-pd62454.html', 30000.0, 'tráng_miệng Chè_hạt_sen')
# 2018-01-31 17:14:10,708 INFO sqlalchemy.engine.base.Engine COMMIT
# 2018-01-31 17:14:10,710 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2018-01-31 17:14:10,711 INFO sqlalchemy.engine.base.Engine INSERT INTO menus (category, title, image, link, price, n_gram_search_text) VALUES (?, ?, ?, ?, ?, ?)
# 2018-01-31 17:14:10,711 INFO sqlalchemy.engine.base.Engine ('món chính', 'Canh chua tôm Sài Gòn', 'http://quananngon.com.vn/mediacenter/media/images/1428/products/1428/1406/s330_330/canh-chua-tom--sai-gon-quan-an-ngon-1498546122.jpg', 'http://quananngon.com.vn/canh-chua-tom-sai-gon-pd63426.html', 125000.0, 'món chính Canh chua tôm Sài_Gòn')
# 2018-01-31 17:14:10,712 INFO sqlalchemy.engine.base.Engine COMMIT
# 2018-01-31 17:14:10,713 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2018-01-31 17:14:10,714 INFO sqlalchemy.engine.base.Engine INSERT INTO menus (category, title, image, link, price, n_gram_search_text) VALUES (?, ?, ?, ?, ?, ?)
# 2018-01-31 17:14:10,715 INFO sqlalchemy.engine.base.Engine ('tráng miệng', 'Chè thập cẩm', 'http://quananngon.com.vn/mediacenter/media/images/products/1428/1406/s330_330/che-thap-cam-quan-an-ngon-1497434204.jpg', 'http://quananngon.com.vn/che-thap-cam-pd62455.html', 28000.0, 'tráng_miệng Chè thập_cẩm')
# 2018-01-31 17:14:10,715 INFO sqlalchemy.engine.base.Engine COMMIT
# 2018-01-31 17:14:10,717 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2018-01-31 17:14:10,717 INFO sqlalchemy.engine.base.Engine INSERT INTO menus (category, title, image, link, price, n_gram_search_text) VALUES (?, ?, ?, ?, ?, ?)
# 2018-01-31 17:14:10,718 INFO sqlalchemy.engine.base.Engine ('món chính', 'Cơm chiên hải sản', 'http://quananngon.com.vn/mediacenter/media/images/products/1428/1406/s330_330/com-chien-hai-san-1496111583.jpg', 'http://quananngon.com.vn/com-chien-hai-san-pd60696.html', 115000.0, 'món chính Cơm_chiên hải_sản')
# 2018-01-31 17:14:10,719 INFO sqlalchemy.engine.base.Engine COMMIT
# 2018-01-31 17:14:10,721 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2018-01-31 17:14:10,722 INFO sqlalchemy.engine.base.Engine INSERT INTO menus (category, title, image, link, price, n_gram_search_text) VALUES (?, ?, ?, ?, ?, ?)
# 2018-01-31 17:14:10,722 INFO sqlalchemy.engine.base.Engine ('món chính', 'Cơm lam muối vừng', 'http://quananngon.com.vn/mediacenter/media/images/1428/products/1428/1406/s330_330/com-lam-muoi-vung-quan-an-ngon-1498467961.jpg', 'http://quananngon.com.vn/com-lam-muoi-vung-pd61197.html', 30000.0, 'món chính Cơm_lam muối_vừng')
# 2018-01-31 17:14:10,723 INFO sqlalchemy.engine.base.Engine COMMIT
# 2018-01-31 17:14:10,725 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2018-01-31 17:14:10,725 INFO sqlalchemy.engine.base.Engine INSERT INTO menus (category, title, image, link, price, n_gram_search_text) VALUES (?, ?, ?, ?, ?, ?)
# 2018-01-31 17:14:10,726 INFO sqlalchemy.engine.base.Engine ('khai vị', 'Nem cua Hải Phòng', 'http://quananngon.com.vn/mediacenter/media/images/1428/products/1428/1406/s330_330/nem-cua-hai-phong-quan-an-ngon-1498471459.jpg', 'http://quananngon.com.vn/nem-cua-hai-phong-pd61429.html', 70000.0, 'khai_vị Nem cua Hải_Phòng')
# 2018-01-31 17:14:10,727 INFO sqlalchemy.engine.base.Engine COMMIT
# 2018-01-31 17:14:10,728 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2018-01-31 17:14:10,729 INFO sqlalchemy.engine.base.Engine INSERT INTO menus (category, title, image, link, price, n_gram_search_text) VALUES (?, ?, ?, ?, ?, ?)
# 2018-01-31 17:14:10,729 INFO sqlalchemy.engine.base.Engine ('tráng miệng', 'Chè ba màu', 'http://quananngon.com.vn/mediacenter/media/images/products/1428/1406/s330_330/che-ba-mau-quan-an-ngon-1497434774.jpg', 'http://quananngon.com.vn/che-ba-mau-pd62456.html', 28000.0, 'tráng_miệng Chè ba màu')
# 2018-01-31 17:14:10,730 INFO sqlalchemy.engine.base.Engine COMMIT
# 2018-01-31 17:14:10,732 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2018-01-31 17:14:10,733 INFO sqlalchemy.engine.base.Engine INSERT INTO menus (category, title, image, link, price, n_gram_search_text) VALUES (?, ?, ?, ?, ?, ?)
# 2018-01-31 17:14:10,733 INFO sqlalchemy.engine.base.Engine ('khai vị', 'Bánh rán nhân thịt', 'http://quananngon.com.vn/mediacenter/media/images/products/1428/1406/s330_330/banh-ran-nhan-thit-quan-an-ngon-1496743819.jpg', 'http://quananngon.com.vn/banh-ran-nhan-thit-pd61439.html', 52000.0, 'khai_vị Bánh_rán nhân thịt')
# 2018-01-31 17:14:10,735 INFO sqlalchemy.engine.base.Engine COMMIT
# 2018-01-31 17:14:10,736 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2018-01-31 17:14:10,737 INFO sqlalchemy.engine.base.Engine INSERT INTO menus (category, title, image, link, price, n_gram_search_text) VALUES (?, ?, ?, ?, ?, ?)
# 2018-01-31 17:14:10,738 INFO sqlalchemy.engine.base.Engine ('khai vị', 'Bánh bao chiên nhân thịt', 'http://quananngon.com.vn/mediacenter/media/images/1428/products/1428/1406/s330_330/banh-bao-chien-quan-an-ngon-1498458307.jpg', 'http://quananngon.com.vn/banh-bao-chien-nhan-thit-pd61442.html', 50000.0, 'khai_vị Bánh_bao chiên nhân thịt')
# 2018-01-31 17:14:10,739 INFO sqlalchemy.engine.base.Engine COMMIT
# 2018-01-31 17:14:10,740 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2018-01-31 17:14:10,742 INFO sqlalchemy.engine.base.Engine INSERT INTO menus (category, title, image, link, price, n_gram_search_text) VALUES (?, ?, ?, ?, ?, ?)
# 2018-01-31 17:14:10,742 INFO sqlalchemy.engine.base.Engine ('khai vị', 'Bánh tôm Hà Nội', 'http://quananngon.com.vn/mediacenter/media/images/1428/products/1428/1406/s330_330/banh-tom-quan-an-ngon-1498459797.jpg', 'http://quananngon.com.vn/banh-tom-ha-noi-pd61435.html', 58000.0, 'khai_vị Bánh_tôm Hà_Nội')
# 2018-01-31 17:14:10,743 INFO sqlalchemy.engine.base.Engine COMMIT
# 2018-01-31 17:14:10,745 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2018-01-31 17:14:10,752 INFO sqlalchemy.engine.base.Engine INSERT INTO menus (category, title, image, link, price, n_gram_search_text) VALUES (?, ?, ?, ?, ?, ?)
# 2018-01-31 17:14:10,754 INFO sqlalchemy.engine.base.Engine ('khai vị', 'Há cảo tôm cua', 'http://quananngon.com.vn/mediacenter/media/images/1428/products/1428/1406/s330_330/ha-cao-quan-an-ngon-1498468513.jpg', 'http://quananngon.com.vn/ha-cao-tom-cua-pd61453.html', 55000.0, 'khai_vị Há cảo tôm cua')
# 2018-01-31 17:14:10,755 INFO sqlalchemy.engine.base.Engine COMMIT
# 2018-01-31 17:14:10,756 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2018-01-31 17:14:10,757 INFO sqlalchemy.engine.base.Engine INSERT INTO menus (category, title, image, link, price, n_gram_search_text) VALUES (?, ?, ?, ?, ?, ?)
# 2018-01-31 17:14:10,757 INFO sqlalchemy.engine.base.Engine ('món chính', 'Nem cua bể', 'http://quananngon.com.vn/mediacenter/media/images/1428/products/1428/1406/s330_330/nem-cua-be-quan-an-ngon-1498471368.jpg', 'http://quananngon.com.vn/nem-cua-be-pd60690.html', 58000.0, 'món chính Nem cua_bể')
# 2018-01-31 17:14:10,758 INFO sqlalchemy.engine.base.Engine COMMIT
# 2018-01-31 17:14:10,759 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2018-01-31 17:14:10,760 INFO sqlalchemy.engine.base.Engine INSERT INTO menus (category, title, image, link, price, n_gram_search_text) VALUES (?, ?, ?, ?, ?, ?)
# 2018-01-31 17:14:10,761 INFO sqlalchemy.engine.base.Engine ('món chính', 'Lẩu bông Miền Tây ', 'http://quananngon.com.vn/mediacenter/media/images/1428/products/1428/1406/s330_330/lau-bong-mien-tay-quan-an-ngon-1498470784.jpg', 'http://quananngon.com.vn/lau-bong-mien-tay-pd60146.html', 365000.0, 'món chính Lẩu bông Miền Tây')
# 2018-01-31 17:14:10,762 INFO sqlalchemy.engine.base.Engine COMMIT
# 2018-01-31 17:14:10,763 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2018-01-31 17:14:10,764 INFO sqlalchemy.engine.base.Engine INSERT INTO menus (category, title, image, link, price, n_gram_search_text) VALUES (?, ?, ?, ?, ?, ?)
# 2018-01-31 17:14:10,765 INFO sqlalchemy.engine.base.Engine ('tráng miệng', 'Chè hoa cau', 'http://quananngon.com.vn/mediacenter/media/images/products/1428/1406/s330_330/che-hoa-cau-quan-an-ngon-1497436188.jpg', 'http://quananngon.com.vn/che-hoa-cau-pd62458.html', 24000.0, 'tráng_miệng Chè hoa_cau')
# 2018-01-31 17:14:10,766 INFO sqlalchemy.engine.base.Engine COMMIT
# 2018-01-31 17:14:10,767 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2018-01-31 17:14:10,768 INFO sqlalchemy.engine.base.Engine INSERT INTO menus (category, title, image, link, price, n_gram_search_text) VALUES (?, ?, ?, ?, ?, ?)
# 2018-01-31 17:14:10,769 INFO sqlalchemy.engine.base.Engine ('khai vị', 'Khoai tây chiên', 'http://quananngon.com.vn/mediacenter/media/images/1428/products/1428/1406/s330_330/khoai-tay-chien-quan-an-ngon-1498470705.jpg', 'http://quananngon.com.vn/khoai-tay-chien-pd62414.html', 55000.0, 'khai_vị Khoai_tây chiên')
# 2018-01-31 17:14:10,770 INFO sqlalchemy.engine.base.Engine COMMIT
# 2018-01-31 17:14:10,771 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2018-01-31 17:14:10,772 INFO sqlalchemy.engine.base.Engine INSERT INTO menus (category, title, image, link, price, n_gram_search_text) VALUES (?, ?, ?, ?, ?, ?)
# 2018-01-31 17:14:10,773 INFO sqlalchemy.engine.base.Engine ('khai vị', 'Bánh bao chay', 'http://quananngon.com.vn/mediacenter/media/images/1428/products/1428/1406/s330_330/banh-bao-chay-quan-an-ngon-1498458113.jpg', 'http://quananngon.com.vn/banh-bao-chay-pd61450.html', 35000.0, 'khai_vị Bánh_bao chay')
# 2018-01-31 17:14:10,774 INFO sqlalchemy.engine.base.Engine COMMIT
# 2018-01-31 17:14:10,775 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2018-01-31 17:14:10,776 INFO sqlalchemy.engine.base.Engine INSERT INTO menus (category, title, image, link, price, n_gram_search_text) VALUES (?, ?, ?, ?, ?, ?)
# 2018-01-31 17:14:10,777 INFO sqlalchemy.engine.base.Engine ('khai vị', 'Nộm bò khô', 'http://quananngon.com.vn/mediacenter/media/images/1428/products/1428/1406/s330_330/nom-bo-kho-quan-an-ngon-1498548245.jpg', 'http://quananngon.com.vn/nom-bo-kho-pd60692.html', 55000.0, 'khai_vị Nộm bò khô')
# 2018-01-31 17:14:10,778 INFO sqlalchemy.engine.base.Engine COMMIT
# 2018-01-31 17:14:10,779 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2018-01-31 17:14:10,780 INFO sqlalchemy.engine.base.Engine INSERT INTO menus (category, title, image, link, price, n_gram_search_text) VALUES (?, ?, ?, ?, ?, ?)
# 2018-01-31 17:14:10,781 INFO sqlalchemy.engine.base.Engine ('khai vị', 'Bánh đúc nóng', 'http://quananngon.com.vn/mediacenter/media/images/products/1428/1406/s330_330/banh-duc-nong-1496816941.jpg', 'http://quananngon.com.vn/banh-duc-nong-pd61467.html', 26000.0, 'khai_vị Bánh_đúc nóng')
# 2018-01-31 17:14:10,782 INFO sqlalchemy.engine.base.Engine COMMIT
# 2018-01-31 17:14:10,783 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2018-01-31 17:14:10,784 INFO sqlalchemy.engine.base.Engine INSERT INTO menus (category, title, image, link, price, n_gram_search_text) VALUES (?, ?, ?, ?, ?, ?)
# 2018-01-31 17:14:10,784 INFO sqlalchemy.engine.base.Engine ('món chính', 'Mực một nắng chiên giòn', 'http://quananngon.com.vn/mediacenter/media/images/1428/products/1428/1406/s330_330/muc-mot-nang--chien-gion-quan-an-ngon-1498548052.jpg', 'http://quananngon.com.vn/muc-mot-nang-chien-gion-pd60103.html', 335000.0, 'món chính Mực một nắng chiên giòn')
# 2018-01-31 17:14:10,785 INFO sqlalchemy.engine.base.Engine COMMIT
# 2018-01-31 17:14:10,786 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2018-01-31 17:14:10,787 INFO sqlalchemy.engine.base.Engine INSERT INTO menus (category, title, image, link, price, n_gram_search_text) VALUES (?, ?, ?, ?, ?, ?)
# 2018-01-31 17:14:10,788 INFO sqlalchemy.engine.base.Engine ('món chính', 'Cơm lam gà nướng', 'http://quananngon.com.vn/mediacenter/media/images/1428/products/1428/1406/s330_330/com-lam-ga-nuong-quan-an-ngon-1498548470.jpg', 'http://quananngon.com.vn/com-lam-ga-nuong-pd61196.html', 95000.0, 'món chính Cơm_lam gà nướng')
# 2018-01-31 17:14:10,789 INFO sqlalchemy.engine.base.Engine COMMIT
# 2018-01-31 17:14:10,790 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2018-01-31 17:14:10,790 INFO sqlalchemy.engine.base.Engine INSERT INTO menus (category, title, image, link, price, n_gram_search_text) VALUES (?, ?, ?, ?, ?, ?)
# 2018-01-31 17:14:10,791 INFO sqlalchemy.engine.base.Engine ('khai vị', 'Bánh xèo nhân tôm thịt ', 'http://quananngon.com.vn/mediacenter/media/images/products/1428/1406/s330_330/800-540-1495425576.jpg', 'http://quananngon.com.vn/banh-xeo-nhan-tom-thit-pd59748.html', 68000.0, 'khai_vị Bánh_xèo nhân tôm thịt')
# 2018-01-31 17:14:10,792 INFO sqlalchemy.engine.base.Engine COMMIT
# 2018-01-31 17:14:10,793 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2018-01-31 17:14:10,794 INFO sqlalchemy.engine.base.Engine INSERT INTO menus (category, title, image, link, price, n_gram_search_text) VALUES (?, ?, ?, ?, ?, ?)
# 2018-01-31 17:14:10,795 INFO sqlalchemy.engine.base.Engine ('khai vị', 'Bánh hỏi heo quay cuốn bánh tráng', 'http://quananngon.com.vn/mediacenter/media/images/1428/products/1428/1406/s330_330/banh-hoi-heo-quay-cuon-banh-trang-quan-an-ngon-1497863122.jpg', 'http://quananngon.com.vn/banh-hoi-heo-quay-cuon-banh-trang-pd63071.html', 110000.0, 'khai_vị Bánh_hỏi heo quay cuốn bánh_tráng')
# 2018-01-31 17:14:10,795 INFO sqlalchemy.engine.base.Engine COMMIT
# 2018-01-31 17:14:10,797 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2018-01-31 17:14:10,798 INFO sqlalchemy.engine.base.Engine INSERT INTO menus (category, title, image, link, price, n_gram_search_text) VALUES (?, ?, ?, ?, ?, ?)
# 2018-01-31 17:14:10,798 INFO sqlalchemy.engine.base.Engine ('khai vị', 'Bánh hỏi bò nướng cuốn bánh tráng', 'http://quananngon.com.vn/mediacenter/media/images/1428/products/1428/1406/s330_330/banh-hoi-bo-nuong-cuon-banh-trang-quan-an-ngon-1498546845.jpg', 'http://quananngon.com.vn/banh-hoi-bo-nuong-cuon-banh-trang-pd63092.html', 135000.0, 'khai_vị Bánh_hỏi bò nướng cuốn bánh_tráng')
# 2018-01-31 17:14:10,799 INFO sqlalchemy.engine.base.Engine COMMIT
# 2018-01-31 17:14:10,801 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2018-01-31 17:14:10,802 INFO sqlalchemy.engine.base.Engine INSERT INTO menus (category, title, image, link, price, n_gram_search_text) VALUES (?, ?, ?, ?, ?, ?)
# 2018-01-31 17:14:10,803 INFO sqlalchemy.engine.base.Engine ('món chính', 'Bún chả kẹp que tre Hà Nội ', 'http://quananngon.com.vn/mediacenter/media/images/products/1428/1406/s330_330/800-540-0-1495428424.jpg', 'http://quananngon.com.vn/bun-cha-kep-que-tre-ha-noi-pd60098.html', 60000.0, 'món chính Bún_chả kẹp que tre Hà_Nội')
# 2018-01-31 17:14:10,804 INFO sqlalchemy.engine.base.Engine COMMIT
# 2018-01-31 17:14:10,805 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2018-01-31 17:14:10,806 INFO sqlalchemy.engine.base.Engine INSERT INTO menus (category, title, image, link, price, n_gram_search_text) VALUES (?, ?, ?, ?, ?, ?)
# 2018-01-31 17:14:10,807 INFO sqlalchemy.engine.base.Engine ('khai vị', 'Bánh hỏi tôm chấy cuốn bánh tráng', 'http://quananngon.com.vn/mediacenter/media/images/1428/products/1428/1406/s330_330/banh-hoi-tom-chay-quan-an-ngon-1498546893.jpg', 'http://quananngon.com.vn/banh-hoi-tom-chay-cuon-banh-trang-pd63090.html', 115000.0, 'khai_vị Bánh_hỏi tôm chấy cuốn bánh_tráng')
# 2018-01-31 17:14:10,808 INFO sqlalchemy.engine.base.Engine COMMIT
# 2018-01-31 17:14:10,810 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2018-01-31 17:14:10,811 INFO sqlalchemy.engine.base.Engine INSERT INTO menus (category, title, image, link, price, n_gram_search_text) VALUES (?, ?, ?, ?, ?, ?)
# 2018-01-31 17:14:10,813 INFO sqlalchemy.engine.base.Engine ('món chính', 'Chả cá Hà Nội', 'http://quananngon.com.vn/mediacenter/media/images/1428/products/1428/1406/s330_330/cha-ca-ha-noi-quan-an-ngon-1498548280.jpg', 'http://quananngon.com.vn/cha-ca-la-vong-pd61199.html', 135000.0, 'món chính Chả cá Hà_Nội')
# 2018-01-31 17:14:10,820 INFO sqlalchemy.engine.base.Engine COMMIT
# 2018-01-31 17:14:10,821 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2018-01-31 17:14:10,822 INFO sqlalchemy.engine.base.Engine INSERT INTO menus (category, title, image, link, price, n_gram_search_text) VALUES (?, ?, ?, ?, ?, ?)
# 2018-01-31 17:14:10,823 INFO sqlalchemy.engine.base.Engine ('khai vị', 'Nộm lươn', 'http://quananngon.com.vn/mediacenter/media/images/1428/products/1428/1406/s330_330/nom-luon-quan-an-ngon-1498551284.jpg', 'http://quananngon.com.vn/nom-luon-pd61410.html', 95000.0, 'khai_vị Nộm_lươn')
# 2018-01-31 17:14:10,824 INFO sqlalchemy.engine.base.Engine COMMIT
# 2018-01-31 17:14:10,825 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2018-01-31 17:14:10,826 INFO sqlalchemy.engine.base.Engine INSERT INTO menus (category, title, image, link, price, n_gram_search_text) VALUES (?, ?, ?, ?, ?, ?)
# 2018-01-31 17:14:10,827 INFO sqlalchemy.engine.base.Engine ('khai vị', 'Xà lách áp chảo thịt bò', 'http://quananngon.com.vn/mediacenter/media/images/1428/products/1428/1406/s330_330/xa-lach-ap-chao-thit-bo-quan-an-ngon-1498554173.jpg', 'http://quananngon.com.vn/xa-lh-ap-chao-thit-bo-pd61414.html', 120000.0, 'khai_vị Xà_lách áp_chảo thịt bò')
# 2018-01-31 17:14:10,828 INFO sqlalchemy.engine.base.Engine COMMIT
# 2018-01-31 17:14:10,829 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2018-01-31 17:14:10,830 INFO sqlalchemy.engine.base.Engine INSERT INTO menus (category, title, image, link, price, n_gram_search_text) VALUES (?, ?, ?, ?, ?, ?)
# 2018-01-31 17:14:10,831 INFO sqlalchemy.engine.base.Engine ('khai vị', 'Bánh xèo nhân thịt bò', 'http://quananngon.com.vn/mediacenter/media/images/1428/products/1428/1406/s330_330/banh-xeo-nhan--thit-bo-quan-an-ngon-1498546732.jpg', 'http://quananngon.com.vn/banh-xeo-nhan-thit-bo-pd63218.html', 68000.0, 'khai_vị Bánh_xèo nhân thịt bò')
# 2018-01-31 17:14:10,832 INFO sqlalchemy.engine.base.Engine COMMIT
# 2018-01-31 17:14:10,833 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2018-01-31 17:14:10,834 INFO sqlalchemy.engine.base.Engine INSERT INTO menus (category, title, image, link, price, n_gram_search_text) VALUES (?, ?, ?, ?, ?, ?)
# 2018-01-31 17:14:10,834 INFO sqlalchemy.engine.base.Engine ('khai vị', 'Xà lách trộn dầu giấm', 'http://quananngon.com.vn/mediacenter/media/images/products/1428/1406/s330_330/xa-lach-tron-dau-dam-2-1496735714.jpg', 'http://quananngon.com.vn/xa-lh-tron-dau-giam-pd61416.html', 55000.0, 'khai_vị Xà_lách trộn dầu giấm')
# 2018-01-31 17:14:10,835 INFO sqlalchemy.engine.base.Engine COMMIT
# 2018-01-31 17:14:10,837 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2018-01-31 17:14:10,838 INFO sqlalchemy.engine.base.Engine INSERT INTO menus (category, title, image, link, price, n_gram_search_text) VALUES (?, ?, ?, ?, ?, ?)
# 2018-01-31 17:14:10,838 INFO sqlalchemy.engine.base.Engine ('khai vị', 'Xà lách cà chua dưa chuột', 'http://quananngon.com.vn/mediacenter/media/images/products/1428/1406/s330_330/xalat-rau-cu-1496736596.jpg', 'http://quananngon.com.vn/xa-lh-ca-chua-dua-chuot-pd61417.html', 55000.0, 'khai_vị Xà_lách cà_chua dưa_chuột')
# 2018-01-31 17:14:10,839 INFO sqlalchemy.engine.base.Engine COMMIT
# 2018-01-31 17:14:10,840 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2018-01-31 17:14:10,841 INFO sqlalchemy.engine.base.Engine INSERT INTO menus (category, title, image, link, price, n_gram_search_text) VALUES (?, ?, ?, ?, ?, ?)
# 2018-01-31 17:14:10,842 INFO sqlalchemy.engine.base.Engine ('khai vị', 'Xà lách trộn dầu dấm', 'http://quananngon.com.vn/mediacenter/media/images/1428/products/1428/1406/s330_330/xa-lach-tron-giau-dam-quan-an-ngon-1497862671.jpg', 'http://quananngon.com.vn/xa-lach-tron-dau-dam-pd63070.html', 55000.0, 'khai_vị Xà_lách trộn dầu dấm')
# 2018-01-31 17:14:10,843 INFO sqlalchemy.engine.base.Engine COMMIT
# 2018-01-31 17:14:10,844 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2018-01-31 17:14:10,845 INFO sqlalchemy.engine.base.Engine INSERT INTO menus (category, title, image, link, price, n_gram_search_text) VALUES (?, ?, ?, ?, ?, ?)
# 2018-01-31 17:14:10,845 INFO sqlalchemy.engine.base.Engine ('món chính', 'Bún riêu cua', 'http://quananngon.com.vn/mediacenter/media/images/products/1428/1406/s330_330/bun-reu-cua-quan-an-ngon-1497431304.jpg', 'http://quananngon.com.vn/bun-rieu-cua-pd62451.html', 55000.0, 'món chính Bún riêu cua')
# 2018-01-31 17:14:10,846 INFO sqlalchemy.engine.base.Engine COMMIT
# 2018-01-31 17:14:10,848 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2018-01-31 17:14:10,849 INFO sqlalchemy.engine.base.Engine INSERT INTO menus (category, title, image, link, price, n_gram_search_text) VALUES (?, ?, ?, ?, ?, ?)
# 2018-01-31 17:14:10,849 INFO sqlalchemy.engine.base.Engine ('món chính', 'Bún thịt luộc mắm tép', 'http://quananngon.com.vn/mediacenter/media/images/products/1428/1406/s330_330/bun-thit-luoc-mam-tep-quan-an-ngon-1497431994.jpg', 'http://quananngon.com.vn/bun-thit-luoc-mam-tep-pd62452.html', 55000.0, 'món chính Bún thịt luộc mắm_tép')
# 2018-01-31 17:14:10,850 INFO sqlalchemy.engine.base.Engine COMMIT
# 2018-01-31 17:14:10,852 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2018-01-31 17:14:10,853 INFO sqlalchemy.engine.base.Engine INSERT INTO menus (category, title, image, link, price, n_gram_search_text) VALUES (?, ?, ?, ?, ?, ?)
# 2018-01-31 17:14:10,853 INFO sqlalchemy.engine.base.Engine ('món chính', 'Hến xúc bánh tráng', 'http://quananngon.com.vn/mediacenter/media/images/1428/products/1428/1406/s330_330/hen-xuc-banh-trang-quan-an-ngon-1498299130.jpg', 'http://quananngon.com.vn/hen-xuc-banh-trang-pd63413.html', 105000.0, 'món chính Hến xúc bánh_tráng')
# 2018-01-31 17:14:10,854 INFO sqlalchemy.engine.base.Engine COMMIT
# 2018-01-31 17:14:10,856 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2018-01-31 17:14:10,857 INFO sqlalchemy.engine.base.Engine INSERT INTO menus (category, title, image, link, price, n_gram_search_text) VALUES (?, ?, ?, ?, ?, ?)
# 2018-01-31 17:14:10,857 INFO sqlalchemy.engine.base.Engine ('khai vị', 'Nộm lạc', 'http://quananngon.com.vn/mediacenter/media/images/1428/products/1428/1406/s330_330/nom-lac-quan-an-ngon-1498550523.jpg', 'http://quananngon.com.vn/nom-l-pd61411.html', 35000.0, 'khai_vị Nộm_lạc')
# 2018-01-31 17:14:10,858 INFO sqlalchemy.engine.base.Engine COMMIT
# 2018-01-31 17:14:10,860 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2018-01-31 17:14:10,862 INFO sqlalchemy.engine.base.Engine INSERT INTO menus (category, title, image, link, price, n_gram_search_text) VALUES (?, ?, ?, ?, ?, ?)
# 2018-01-31 17:14:10,862 INFO sqlalchemy.engine.base.Engine ('khai vị', 'Súp cua măng tây', 'http://quananngon.com.vn/mediacenter/media/images/1428/products/1428/1406/s330_330/sup-cua-mang-tay-quan-an-ngon-1498546777.jpg', 'http://quananngon.com.vn/sup-cua-mang-tay-pd63193.html', 55000.0, 'khai_vị Súp_cua măng_tây')
# 2018-01-31 17:14:10,863 INFO sqlalchemy.engine.base.Engine COMMIT
# 2018-01-31 17:14:10,864 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2018-01-31 17:14:10,867 INFO sqlalchemy.engine.base.Engine INSERT INTO menus (category, title, image, link, price, n_gram_search_text) VALUES (?, ?, ?, ?, ?, ?)
# 2018-01-31 17:14:10,867 INFO sqlalchemy.engine.base.Engine ('món chính', 'Bò nướng lá lốt', 'http://quananngon.com.vn/mediacenter/media/images/1428/products/1428/1406/s330_330/bo-nuong-la-lot-quan-an-ngon-1498546487.jpg', 'http://quananngon.com.vn/bo-nuong-la-lot-pd63418.html', 140000.0, 'món chính Bò nướng lá_lốt')
# 2018-01-31 17:14:10,868 INFO sqlalchemy.engine.base.Engine COMMIT
# 2018-01-31 17:14:10,871 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2018-01-31 17:14:10,872 INFO sqlalchemy.engine.base.Engine INSERT INTO menus (category, title, image, link, price, n_gram_search_text) VALUES (?, ?, ?, ?, ?, ?)
# 2018-01-31 17:14:10,872 INFO sqlalchemy.engine.base.Engine ('khai vị', 'Nộm chim cút', 'http://quananngon.com.vn/mediacenter/media/images/1428/products/1428/1406/s330_330/nom-chim-cut-quan-an-ngon-1498550432.jpg', 'http://quananngon.com.vn/nom-chim-cut-pd61400.html', 55000.0, 'khai_vị Nộm chim_cút')
# 2018-01-31 17:14:10,873 INFO sqlalchemy.engine.base.Engine COMMIT
# 2018-01-31 17:14:10,876 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2018-01-31 17:14:10,877 INFO sqlalchemy.engine.base.Engine INSERT INTO menus (category, title, image, link, price, n_gram_search_text) VALUES (?, ?, ?, ?, ?, ?)
# 2018-01-31 17:14:10,877 INFO sqlalchemy.engine.base.Engine ('món chính', 'Lẩu cá song', 'http://quananngon.com.vn/mediacenter/media/images/1428/products/1428/1406/s330_330/lau-ca-song-quan-an-ngon-1498546436.jpg', 'http://quananngon.com.vn/lau-ca-song-pd63419.html', 950000.0, 'món chính Lẩu cá_song')
# 2018-01-31 17:14:10,878 INFO sqlalchemy.engine.base.Engine COMMIT
# 2018-01-31 17:14:10,883 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2018-01-31 17:14:10,884 INFO sqlalchemy.engine.base.Engine INSERT INTO menus (category, title, image, link, price, n_gram_search_text) VALUES (?, ?, ?, ?, ?, ?)
# 2018-01-31 17:14:10,885 INFO sqlalchemy.engine.base.Engine ('món chính', 'Nghêu vàng nướng mỡ hành', 'http://quananngon.com.vn/mediacenter/media/images/1428/products/1428/1406/s330_330/ngeu-vang-nuong-mo-hanh-quan-an-ngon-1497941827.jpg', 'http://quananngon.com.vn/ngheu-vang-nuong-mo-hanh-pd63414.html', 120000.0, 'món chính Nghêu vàng nướng mỡ hành')
# 2018-01-31 17:14:10,886 INFO sqlalchemy.engine.base.Engine COMMIT
# 2018-01-31 17:14:10,887 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2018-01-31 17:14:10,888 INFO sqlalchemy.engine.base.Engine INSERT INTO menus (category, title, image, link, price, n_gram_search_text) VALUES (?, ?, ?, ?, ?, ?)
# 2018-01-31 17:14:10,889 INFO sqlalchemy.engine.base.Engine ('món chính', 'Cá song nướng muối ớt', 'http://quananngon.com.vn/mediacenter/media/images/1428/products/1428/1406/s330_330/ca-song-nuong-muoi-ot-quan-an-ngon-1498546649.jpg', 'http://quananngon.com.vn/ca-song-nuong-muoi-ot-pd63416.html', 950000.0, 'món chính Cá_song nướng muối ớt')
# 2018-01-31 17:14:10,890 INFO sqlalchemy.engine.base.Engine COMMIT
# 2018-01-31 17:14:10,891 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2018-01-31 17:14:10,891 INFO sqlalchemy.engine.base.Engine INSERT INTO menus (category, title, image, link, price, n_gram_search_text) VALUES (?, ?, ?, ?, ?, ?)
# 2018-01-31 17:14:10,892 INFO sqlalchemy.engine.base.Engine ('món chính', 'Thịt kho tộ', 'http://quananngon.com.vn/mediacenter/media/images/1428/products/1428/1406/s330_330/thit-bo-kho-to-quan-an-ngon-1498546264.jpg', 'http://quananngon.com.vn/thit-kho-to-pd63423.html', 95000.0, 'món chính Thịt kho_tộ')
# 2018-01-31 17:14:10,893 INFO sqlalchemy.engine.base.Engine COMMIT
# 2018-01-31 17:14:10,894 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2018-01-31 17:14:10,894 INFO sqlalchemy.engine.base.Engine INSERT INTO menus (category, title, image, link, price, n_gram_search_text) VALUES (?, ?, ?, ?, ?, ?)
# 2018-01-31 17:14:10,895 INFO sqlalchemy.engine.base.Engine ('khai vị', 'Nem cuốn', 'http://quananngon.com.vn/mediacenter/media/images/1428/products/1428/1406/s330_330/nem-cuon-quan-an-ngon-1498471539.jpg', 'http://quananngon.com.vn/nem-cuon-pd61426.html', 16000.0, 'khai_vị Nem cuốn')
# 2018-01-31 17:14:10,896 INFO sqlalchemy.engine.base.Engine COMMIT
# 2018-01-31 17:14:10,898 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2018-01-31 17:14:10,900 INFO sqlalchemy.engine.base.Engine INSERT INTO menus (category, title, image, link, price, n_gram_search_text) VALUES (?, ?, ?, ?, ?, ?)
# 2018-01-31 17:14:10,901 INFO sqlalchemy.engine.base.Engine ('món chính', 'Xôi xéo gà quay', 'http://quananngon.com.vn/mediacenter/media/images/1428/products/1428/1406/s330_330/xoi-xeo-ga-quay-quan-an-ngon-1498546394.jpg', 'http://quananngon.com.vn/xoi-xeo-ga-quay-pd63420.html', 85000.0, 'món chính Xôi_xéo gà quay')
# 2018-01-31 17:14:10,902 INFO sqlalchemy.engine.base.Engine COMMIT
# 2018-01-31 17:14:10,903 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2018-01-31 17:14:10,904 INFO sqlalchemy.engine.base.Engine INSERT INTO menus (category, title, image, link, price, n_gram_search_text) VALUES (?, ?, ?, ?, ?, ?)
# 2018-01-31 17:14:10,904 INFO sqlalchemy.engine.base.Engine ('món chính', 'Cơm tấm sườn bì', 'http://quananngon.com.vn/mediacenter/media/images/products/1428/1406/s330_330/com-tam-suon-bi-quan-an-ngon-1497424224.jpg', 'http://quananngon.com.vn/com-tam-suon-bi-pd62438.html', 60000.0, 'món chính Cơm tấm sườn bì')
# 2018-01-31 17:14:10,905 INFO sqlalchemy.engine.base.Engine COMMIT
# 2018-01-31 17:14:10,906 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2018-01-31 17:14:10,907 INFO sqlalchemy.engine.base.Engine INSERT INTO menus (category, title, image, link, price, n_gram_search_text) VALUES (?, ?, ?, ?, ?, ?)
# 2018-01-31 17:14:10,908 INFO sqlalchemy.engine.base.Engine ('món chính', 'Cơm tấm bì thịt nướng', 'http://quananngon.com.vn/mediacenter/media/images/1428/products/1428/1406/s330_330/com-tam-bi-thit-nuong-quan-an-ngon-1498468244.jpg', 'http://quananngon.com.vn/com-tam-bi-thit-nuong-pd62439.html', 60000.0, 'món chính Cơm tấm bì thịt nướng')
# 2018-01-31 17:14:10,908 INFO sqlalchemy.engine.base.Engine COMMIT
# 2018-01-31 17:14:10,909 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2018-01-31 17:14:10,910 INFO sqlalchemy.engine.base.Engine INSERT INTO menus (category, title, image, link, price, n_gram_search_text) VALUES (?, ?, ?, ?, ?, ?)
# 2018-01-31 17:14:10,911 INFO sqlalchemy.engine.base.Engine ('món chính', 'Gỏi cuốn tôm thịt ', 'http://quananngon.com.vn/mediacenter/media/images/1428/products/1428/1406/s330_330/goi-cuon-tom-thit-quan-an-ngon-1498467591.jpg', 'http://quananngon.com.vn/goi-cuon-tom-thit-quan-an-ngon-pd60104.html', 20000.0, 'món chính Gỏi cuốn tôm thịt')
# 2018-01-31 17:14:10,912 INFO sqlalchemy.engine.base.Engine COMMIT
# 2018-01-31 17:14:10,913 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2018-01-31 17:14:10,914 INFO sqlalchemy.engine.base.Engine INSERT INTO menus (category, title, image, link, price, n_gram_search_text) VALUES (?, ?, ?, ?, ?, ?)
# 2018-01-31 17:14:10,914 INFO sqlalchemy.engine.base.Engine ('món chính', 'Xôi ngô ', 'http://quananngon.com.vn/mediacenter/media/images/1428/products/1428/1406/s330_330/xoi-ngo-1501062797.jpg', 'http://quananngon.com.vn/xoi-ngo-pd62441.html', 25000.0, 'món chính Xôi_ngô')
# 2018-01-31 17:14:10,915 INFO sqlalchemy.engine.base.Engine COMMIT
# 2018-01-31 17:14:10,916 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2018-01-31 17:14:10,917 INFO sqlalchemy.engine.base.Engine INSERT INTO menus (category, title, image, link, price, n_gram_search_text) VALUES (?, ?, ?, ?, ?, ?)
# 2018-01-31 17:14:10,917 INFO sqlalchemy.engine.base.Engine ('món chính', 'Phở gà', 'http://quananngon.com.vn/mediacenter/media/images/1428/products/1428/1406/s330_330/pho-ga-quan-an-ngon-1498552042.jpg', 'http://quananngon.com.vn/pho-ga-pd62443.html', 58000.0, 'món chính Phở gà')
# 2018-01-31 17:14:10,918 INFO sqlalchemy.engine.base.Engine COMMIT
# 2018-01-31 17:14:10,919 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2018-01-31 17:14:10,920 INFO sqlalchemy.engine.base.Engine INSERT INTO menus (category, title, image, link, price, n_gram_search_text) VALUES (?, ?, ?, ?, ?, ?)
# 2018-01-31 17:14:10,920 INFO sqlalchemy.engine.base.Engine ('món chính', 'Cơm tấm sườn chả', 'http://quananngon.com.vn/mediacenter/media/images/products/1428/1406/s330_330/com-tam-bi-suon-cha-quan-an-ngon-1497425612.jpg', 'http://quananngon.com.vn/com-tam-suon-cha-pd62440.html', 60000.0, 'món chính Cơm tấm sườn chả')
# 2018-01-31 17:14:10,921 INFO sqlalchemy.engine.base.Engine COMMIT
# 2018-01-31 17:14:10,922 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2018-01-31 17:14:10,923 INFO sqlalchemy.engine.base.Engine INSERT INTO menus (category, title, image, link, price, n_gram_search_text) VALUES (?, ?, ?, ?, ?, ?)
# 2018-01-31 17:14:10,924 INFO sqlalchemy.engine.base.Engine ('món chính', 'Chim câu nướng lá chanh', 'http://quananngon.com.vn/mediacenter/media/images/1428/products/1428/1406/s330_330/chim-cau-nuong-la-chanh-quan-an-ngon-1498546320.jpg', 'http://quananngon.com.vn/chim-cau-nuong-la-chanh-pd63421.html', 160000.0, 'món chính Chim câu nướng lá_chanh')
# 2018-01-31 17:14:10,924 INFO sqlalchemy.engine.base.Engine COMMIT
# 2018-01-31 17:14:10,926 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2018-01-31 17:14:10,927 INFO sqlalchemy.engine.base.Engine INSERT INTO menus (category, title, image, link, price, n_gram_search_text) VALUES (?, ?, ?, ?, ?, ?)
# 2018-01-31 17:14:10,927 INFO sqlalchemy.engine.base.Engine ('món chính', 'Phở bò', 'http://quananngon.com.vn/mediacenter/media/images/1428/products/1428/1406/s330_330/pho-bo-chin-quan-an-ngon-1498551790.jpg', 'http://quananngon.com.vn/pho-bo-pd62442.html', 58000.0, 'món chính Phở_bò')
# 2018-01-31 17:14:10,928 INFO sqlalchemy.engine.base.Engine COMMIT
# 2018-01-31 17:14:10,930 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2018-01-31 17:14:10,931 INFO sqlalchemy.engine.base.Engine INSERT INTO menus (category, title, image, link, price, n_gram_search_text) VALUES (?, ?, ?, ?, ?, ?)
# 2018-01-31 17:14:10,931 INFO sqlalchemy.engine.base.Engine ('khai vị', 'Gỏi cuốn tai heo chấm mắm nêm', 'http://quananngon.com.vn/mediacenter/media/images/products/1428/1406/s330_330/goi-cuon-tai-heo-10-1496737440.jpg', 'http://quananngon.com.vn/goi-cuon-tai-heo-cham-mam-nem-pd61419.html', 18000.0, 'khai_vị Gỏi cuốn tai heo chấm mắm_nêm')
# 2018-01-31 17:14:10,933 INFO sqlalchemy.engine.base.Engine COMMIT
# 2018-01-31 17:14:10,934 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2018-01-31 17:14:10,935 INFO sqlalchemy.engine.base.Engine INSERT INTO menus (category, title, image, link, price, n_gram_search_text) VALUES (?, ?, ?, ?, ?, ?)
# 2018-01-31 17:14:10,936 INFO sqlalchemy.engine.base.Engine ('món chính', 'Cá song hấp xì dầu cuốn bánh tráng', 'http://quananngon.com.vn/mediacenter/media/images/1428/products/1428/1406/s330_330/ca-song-hap-xi-dau-cuon-banh-trang-quan-an-ngon-1498546583.jpg', 'http://quananngon.com.vn/ca-song-hap-xi-dau-cuon-banh-trang-pd63417.html', 950000.0, 'món chính Cá_song hấp xì_dầu cuốn bánh_tráng')
# 2018-01-31 17:14:10,937 INFO sqlalchemy.engine.base.Engine COMMIT
# 2018-01-31 17:14:10,938 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2018-01-31 17:14:10,940 INFO sqlalchemy.engine.base.Engine INSERT INTO menus (category, title, image, link, price, n_gram_search_text) VALUES (?, ?, ?, ?, ?, ?)
# 2018-01-31 17:14:10,947 INFO sqlalchemy.engine.base.Engine ('khai vị', 'Súp gà', 'http://quananngon.com.vn/mediacenter/media/images/1428/products/1428/1406/s330_330/sup-ga-quan-an-ngon-1498552602.jpg', 'http://quananngon.com.vn/sup-ga-pd61391.html', 30000.0, 'khai_vị Súp gà')
# 2018-01-31 17:14:10,948 INFO sqlalchemy.engine.base.Engine COMMIT
# 2018-01-31 17:14:10,949 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2018-01-31 17:14:10,950 INFO sqlalchemy.engine.base.Engine INSERT INTO menus (category, title, image, link, price, n_gram_search_text) VALUES (?, ?, ?, ?, ?, ?)
# 2018-01-31 17:14:10,951 INFO sqlalchemy.engine.base.Engine ('món chính', 'Bún ốc om chuối đậu', 'http://quananngon.com.vn/mediacenter/media/images/1428/products/1428/1406/s330_330/oc-om-chuoi-dau-quan-an-ngon-1498551642.jpg', 'http://quananngon.com.vn/bun-oc-om-chuoi-dau-pd62445.html', 60000.0, 'món chính Bún ốc om_chuối đậu')
# 2018-01-31 17:14:10,952 INFO sqlalchemy.engine.base.Engine COMMIT
# 2018-01-31 17:14:10,953 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2018-01-31 17:14:10,954 INFO sqlalchemy.engine.base.Engine INSERT INTO menus (category, title, image, link, price, n_gram_search_text) VALUES (?, ?, ?, ?, ?, ?)
# 2018-01-31 17:14:10,955 INFO sqlalchemy.engine.base.Engine ('món chính', 'Bún nem nướng', 'http://quananngon.com.vn/mediacenter/media/images/products/1428/1406/s330_330/bun-mem-nuong-quan-an-ngon-1497429549.jpg', 'http://quananngon.com.vn/bun-nem-nuong-pd62446.html', 60000.0, 'món chính Bún nem nướng')
# 2018-01-31 17:14:10,956 INFO sqlalchemy.engine.base.Engine COMMIT
# 2018-01-31 17:14:10,957 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2018-01-31 17:14:10,958 INFO sqlalchemy.engine.base.Engine INSERT INTO menus (category, title, image, link, price, n_gram_search_text) VALUES (?, ?, ?, ?, ?, ?)
# 2018-01-31 17:14:10,959 INFO sqlalchemy.engine.base.Engine ('khai vị', 'Gỏi bò bóp thấu', 'http://quananngon.com.vn/mediacenter/media/images/products/1428/1406/s330_330/goi-bo-bop-thau-chon-1-1496729076.jpg', 'http://quananngon.com.vn/goi-bo-bop-thau-pd61396.html', 120000.0, 'khai_vị Gỏi bò bóp thấu')
# 2018-01-31 17:14:10,960 INFO sqlalchemy.engine.base.Engine COMMIT
# 2018-01-31 17:14:10,961 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2018-01-31 17:14:10,963 INFO sqlalchemy.engine.base.Engine INSERT INTO menus (category, title, image, link, price, n_gram_search_text) VALUES (?, ?, ?, ?, ?, ?)
# 2018-01-31 17:14:10,963 INFO sqlalchemy.engine.base.Engine ('khai vị', 'Gỏi ngó sen tôm thịt', 'http://quananngon.com.vn/mediacenter/media/images/1428/products/1428/1406/s330_330/goi-ngo-sen-tom-thit-quan-an-ngon-1498469333.jpg', 'http://quananngon.com.vn/goi-ngo-sen-tom-thit-pd61395.html', 120000.0, 'khai_vị Gỏi ngó sen tôm thịt')
# 2018-01-31 17:14:10,964 INFO sqlalchemy.engine.base.Engine COMMIT
# 2018-01-31 17:14:10,965 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2018-01-31 17:14:10,967 INFO sqlalchemy.engine.base.Engine INSERT INTO menus (category, title, image, link, price, n_gram_search_text) VALUES (?, ?, ?, ?, ?, ?)
# 2018-01-31 17:14:10,967 INFO sqlalchemy.engine.base.Engine ('khai vị', 'Súp lươn', 'http://quananngon.com.vn/mediacenter/media/images/1428/products/1428/1406/s330_330/sup-luon-quan-an-ngon-1498552713.jpg', 'http://quananngon.com.vn/sup-luon-pd61393.html', 30000.0, 'khai_vị Súp_lươn')
# 2018-01-31 17:14:10,968 INFO sqlalchemy.engine.base.Engine COMMIT
# 2018-01-31 17:14:10,970 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2018-01-31 17:14:10,971 INFO sqlalchemy.engine.base.Engine INSERT INTO menus (category, title, image, link, price, n_gram_search_text) VALUES (?, ?, ?, ?, ?, ?)
# 2018-01-31 17:14:10,971 INFO sqlalchemy.engine.base.Engine ('món chính', 'Sủi cảo tôm tươi', 'http://quananngon.com.vn/mediacenter/media/images/1428/products/1428/1406/s330_330/sui-cao-tom-tuoi-quan-an-ngon-1498552364.jpg', 'http://quananngon.com.vn/sui-cao-tom-tuoi-pd62449.html', 55000.0, 'món chính Sủi cảo tôm tươi')
# 2018-01-31 17:14:10,972 INFO sqlalchemy.engine.base.Engine COMMIT
# 2018-01-31 17:14:10,973 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2018-01-31 17:14:10,974 INFO sqlalchemy.engine.base.Engine INSERT INTO menus (category, title, image, link, price, n_gram_search_text) VALUES (?, ?, ?, ?, ?, ?)
# 2018-01-31 17:14:10,975 INFO sqlalchemy.engine.base.Engine ('khai vị', 'Gỏi gà Hội An', 'http://quananngon.com.vn/mediacenter/media/images/products/1428/1406/s330_330/goi-ga-xe-phay-1-1496730378.jpg', 'http://quananngon.com.vn/goi-ga-hoi-an-pd61398.html', 165000.0, 'khai_vị Gỏi gà Hội_An')
# 2018-01-31 17:14:10,975 INFO sqlalchemy.engine.base.Engine COMMIT
# 2018-01-31 17:14:10,977 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2018-01-31 17:14:10,977 INFO sqlalchemy.engine.base.Engine INSERT INTO menus (category, title, image, link, price, n_gram_search_text) VALUES (?, ?, ?, ?, ?, ?)
# 2018-01-31 17:14:10,978 INFO sqlalchemy.engine.base.Engine ('khai vị', ' Gỏi xoài hải sản', 'http://quananngon.com.vn/mediacenter/media/images/1428/products/1428/1406/s330_330/goi-xoai-hai-san-quan-an-ngon-1498469821.jpg', 'http://quananngon.com.vn/goi-xoai-hai-san-pd61397.html', 130000.0, 'khai_vị Gỏi xoài hải_sản')
# 2018-01-31 17:14:10,979 INFO sqlalchemy.engine.base.Engine COMMIT
# 2018-01-31 17:14:10,980 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2018-01-31 17:14:10,981 INFO sqlalchemy.engine.base.Engine INSERT INTO menus (category, title, image, link, price, n_gram_search_text) VALUES (?, ?, ?, ?, ?, ?)
# 2018-01-31 17:14:10,982 INFO sqlalchemy.engine.base.Engine ('khai vị', 'Gỏi cổ hũ dừa tôm thịt', 'http://quananngon.com.vn/mediacenter/media/images/1428/products/1428/1406/s330_330/goi-co-hu-dua-tom-thit-quan-an-ngon-1498547043.jpg', 'http://quananngon.com.vn/goi-co-hu-dua-tom-thit-pd63075.html', 130000.0, 'khai_vị Gỏi cổ_hũ dừa tôm thịt')
# 2018-01-31 17:14:10,982 INFO sqlalchemy.engine.base.Engine COMMIT
# 2018-01-31 17:14:10,984 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2018-01-31 17:14:10,984 INFO sqlalchemy.engine.base.Engine INSERT INTO menus (category, title, image, link, price, n_gram_search_text) VALUES (?, ?, ?, ?, ?, ?)
# 2018-01-31 17:14:10,985 INFO sqlalchemy.engine.base.Engine ('khai vị', 'Xúp cua bể măng tây', 'http://quananngon.com.vn/mediacenter/media/images/1428/products/1428/1406/s330_330/sup-cua-mang-tay-quan-an-ngon-1498547146.jpg', 'http://quananngon.com.vn/xup-cua-be-mang-tay-pd63074.html', 55000.0, 'khai_vị Xúp cua_bể măng_tây')
# 2018-01-31 17:14:10,986 INFO sqlalchemy.engine.base.Engine COMMIT
# 2018-01-31 17:14:10,987 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2018-01-31 17:14:10,988 INFO sqlalchemy.engine.base.Engine INSERT INTO menus (category, title, image, link, price, n_gram_search_text) VALUES (?, ?, ?, ?, ?, ?)
# 2018-01-31 17:14:10,988 INFO sqlalchemy.engine.base.Engine ('khai vị', 'Bánh xèo nhân hải sản', 'http://quananngon.com.vn/mediacenter/media/images/1428/products/1428/1406/s330_330/banh-xeo-nhan--hai-san-quan-an-ngon-1498546953.jpg', 'http://quananngon.com.vn/banh-xeo-nhan-hai-san-pd63087.html', 68000.0, 'khai_vị Bánh_xèo nhân hải_sản')
# 2018-01-31 17:14:10,989 INFO sqlalchemy.engine.base.Engine COMMIT
# 2018-01-31 17:14:10,990 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2018-01-31 17:14:10,991 INFO sqlalchemy.engine.base.Engine INSERT INTO menus (category, title, image, link, price, n_gram_search_text) VALUES (?, ?, ?, ?, ?, ?)
# 2018-01-31 17:14:10,992 INFO sqlalchemy.engine.base.Engine ('món chính', 'Bánh giò', 'http://quananngon.com.vn/mediacenter/media/images/products/1428/1406/s330_330/banh-gio-quan-an-ngon-1497432670.jpg', 'http://quananngon.com.vn/banh-gio-pd62453.html', 26000.0, 'món chính Bánh_giò')
# 2018-01-31 17:14:10,992 INFO sqlalchemy.engine.base.Engine COMMIT
# 2018-01-31 17:14:10,994 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2018-01-31 17:14:10,994 INFO sqlalchemy.engine.base.Engine INSERT INTO menus (category, title, image, link, price, n_gram_search_text) VALUES (?, ?, ?, ?, ?, ?)
# 2018-01-31 17:14:10,995 INFO sqlalchemy.engine.base.Engine ('khai vị', 'Nộm thập cẩm', 'http://quananngon.com.vn/mediacenter/media/images/1428/products/1428/1406/s330_330/nom-thap-cam-quan-an-ngon-1498551410.jpg', 'http://quananngon.com.vn/nom-thap-cam-pd61399.html', 55000.0, 'khai_vị Nộm thập_cẩm')
# 2018-01-31 17:14:10,996 INFO sqlalchemy.engine.base.Engine COMMIT
# 2018-01-31 17:14:10,997 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2018-01-31 17:14:10,998 INFO sqlalchemy.engine.base.Engine INSERT INTO menus (category, title, image, link, price, n_gram_search_text) VALUES (?, ?, ?, ?, ?, ?)
# 2018-01-31 17:14:10,998 INFO sqlalchemy.engine.base.Engine ('món chính', 'Bún dọc mùng chân giò', 'http://quananngon.com.vn/mediacenter/media/images/1428/products/1428/1406/s330_330/bun-doc-mung-quan-an-ngon-1498461895.jpg', 'http://quananngon.com.vn/bun-doc-mung-chan-gio-pd62444.html', 55000.0, 'món chính Bún dọc mùng chân_giò')
# 2018-01-31 17:14:10,999 INFO sqlalchemy.engine.base.Engine COMMIT
# 2018-01-31 17:14:11,000 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2018-01-31 17:14:11,001 INFO sqlalchemy.engine.base.Engine INSERT INTO menus (category, title, image, link, price, n_gram_search_text) VALUES (?, ?, ?, ?, ?, ?)
# 2018-01-31 17:14:11,002 INFO sqlalchemy.engine.base.Engine ('khai vị', 'Nộm chim sẻ', 'http://quananngon.com.vn/mediacenter/media/images/1428/products/1428/1406/s330_330/nom-chim-se-quan-an-ngon-1498547468.jpg', 'http://quananngon.com.vn/nom-chim-se-pd61401.html', 55000.0, 'khai_vị Nộm chim_sẻ')
# 2018-01-31 17:14:11,002 INFO sqlalchemy.engine.base.Engine COMMIT
# 2018-01-31 17:14:11,003 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2018-01-31 17:14:11,004 INFO sqlalchemy.engine.base.Engine INSERT INTO menus (category, title, image, link, price, n_gram_search_text) VALUES (?, ?, ?, ?, ?, ?)
# 2018-01-31 17:14:11,005 INFO sqlalchemy.engine.base.Engine ('món chính', 'Mỳ vằn thắn', 'http://quananngon.com.vn/mediacenter/media/images/products/1428/1406/s330_330/my-van-than-quan-an-ngon-1497429996.jpg', 'http://quananngon.com.vn/my-van-than-pd62448.html', 58000.0, 'món chính Mỳ vằn_thắn')
# 2018-01-31 17:14:11,005 INFO sqlalchemy.engine.base.Engine COMMIT
# 2018-01-31 17:14:11,007 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# ...
# 2018-01-31 17:14:11,440 INFO sqlalchemy.engine.base.Engine COMMIT
# 2018-01-31 17:14:11,442 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2018-01-31 17:14:11,443 INFO sqlalchemy.engine.base.Engine INSERT INTO menus (category, title, image, link, price, n_gram_search_text) VALUES (?, ?, ?, ?, ?, ?)
# 2018-01-31 17:14:11,444 INFO sqlalchemy.engine.base.Engine ('món chính', 'Hủ tiếu Nam Vang khô', 'http://quananngon.com.vn/mediacenter/media/images/1428/products/1428/1406/s330_330/hu-tieu-kho-1501063365.jpg', 'http://quananngon.com.vn/hu-tieu-nam-vang-kho-pd61381.html', 60000.0, 'món chính Hủ_tiếu Nam Vang khô')
# 2018-01-31 17:14:11,445 INFO sqlalchemy.engine.base.Engine COMMIT
# 2018-01-31 17:14:11,446 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2018-01-31 17:14:11,447 INFO sqlalchemy.engine.base.Engine INSERT INTO menus (category, title, image, link, price, n_gram_search_text) VALUES (?, ?, ?, ?, ?, ?)
# 2018-01-31 17:14:11,448 INFO sqlalchemy.engine.base.Engine ('món chính', 'Bánh quẩy', 'http://quananngon.com.vn/mediacenter/media/images/products/1428/1406/s330_330/banh-quay-quan-an-ngon-1496804560.jpg', 'http://quananngon.com.vn/banh-quay-pd61455.html', 15000.0, 'món chính Bánh_quẩy')
# 2018-01-31 17:14:11,449 INFO sqlalchemy.engine.base.Engine COMMIT
# 2018-01-31 17:14:11,451 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2018-01-31 17:14:11,451 INFO sqlalchemy.engine.base.Engine INSERT INTO menus (category, title, image, link, price, n_gram_search_text) VALUES (?, ?, ?, ?, ?, ?)
# 2018-01-31 17:14:11,452 INFO sqlalchemy.engine.base.Engine ('món chính', 'Bún bò Nam Bộ', 'http://quananngon.com.vn/mediacenter/media/images/products/1428/1406/s330_330/bun-bo-nam-bo-1496721350.jpg', 'http://quananngon.com.vn/bun-bo-nam-bo-pd61384.html', 65000.0, 'món chính Bún_bò Nam_Bộ')
# 2018-01-31 17:14:11,454 INFO sqlalchemy.engine.base.Engine COMMIT
# 2018-01-31 17:14:11,458 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2018-01-31 17:14:11,462 INFO sqlalchemy.engine.base.Engine INSERT INTO menus (category, title, image, link, price, n_gram_search_text) VALUES (?, ?, ?, ?, ?, ?)
# 2018-01-31 17:14:11,464 INFO sqlalchemy.engine.base.Engine ('món chính', 'Bánh cuốn nhân thịt', 'http://quananngon.com.vn/mediacenter/media/images/products/1428/1406/s330_330/banh-cuon-nong-nhan-thit-1-1496717532.jpg', 'http://quananngon.com.vn/banh-cuon-nhan-thit-pd61214.html', 55000.0, 'món chính Bánh_cuốn nhân thịt')
# 2018-01-31 17:14:11,465 INFO sqlalchemy.engine.base.Engine COMMIT
# 2018-01-31 17:14:11,466 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2018-01-31 17:14:11,467 INFO sqlalchemy.engine.base.Engine INSERT INTO menus (category, title, image, link, price, n_gram_search_text) VALUES (?, ?, ?, ?, ?, ?)
# 2018-01-31 17:14:11,468 INFO sqlalchemy.engine.base.Engine ('món chính', 'Mỳ Quảng', 'http://quananngon.com.vn/mediacenter/media/images/products/1428/1406/s330_330/my-quang-7-1496717624.jpg', 'http://quananngon.com.vn/my-quang-pd61212.html', 60000.0, 'món chính Mỳ_Quảng')
# 2018-01-31 17:14:11,469 INFO sqlalchemy.engine.base.Engine COMMIT
# 2018-01-31 17:14:11,470 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2018-01-31 17:14:11,471 INFO sqlalchemy.engine.base.Engine INSERT INTO menus (category, title, image, link, price, n_gram_search_text) VALUES (?, ?, ?, ?, ?, ?)
# 2018-01-31 17:14:11,472 INFO sqlalchemy.engine.base.Engine ('món chính', 'Bánh khọt vũng tàu', 'http://quananngon.com.vn/mediacenter/media/images/1428/products/1428/1406/s330_330/banh-khot-vung--tau-quan-an-ngon-1498459331.jpg', 'http://quananngon.com.vn/banh-khot-vung-tau-pd61213.html', 65000.0, 'món chính Bánh_khọt vũng_tàu')
# 2018-01-31 17:14:11,474 INFO sqlalchemy.engine.base.Engine COMMIT
# 2018-01-31 17:14:11,475 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2018-01-31 17:14:11,476 INFO sqlalchemy.engine.base.Engine INSERT INTO menus (category, title, image, link, price, n_gram_search_text) VALUES (?, ?, ?, ?, ?, ?)
# 2018-01-31 17:14:11,477 INFO sqlalchemy.engine.base.Engine ('món chính', 'Bánh tráng Trảng Bàng', 'http://quananngon.com.vn/mediacenter/media/images/products/1428/1406/s330_330/banh-trang-trang-bang-1496717215.jpg', 'http://quananngon.com.vn/banh-trang-trang-bang-pd61226.html', 145000.0, 'món chính Bánh_tráng Trảng_Bàng')
# 2018-01-31 17:14:11,477 INFO sqlalchemy.engine.base.Engine COMMIT
# 2018-01-31 17:14:11,479 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2018-01-31 17:14:11,480 INFO sqlalchemy.engine.base.Engine INSERT INTO menus (category, title, image, link, price, n_gram_search_text) VALUES (?, ?, ?, ?, ?, ?)
# 2018-01-31 17:14:11,481 INFO sqlalchemy.engine.base.Engine ('món chính', 'Bánh cuốn nhân tôm', 'http://quananngon.com.vn/mediacenter/media/images/1428/products/1428/1406/s330_330/banh-cuon-nhan--tom-quan-an-ngon-1498458784.jpg', 'http://quananngon.com.vn/banh-cuon-nhan-tom-pd61221.html', 55000.0, 'món chính Bánh_cuốn nhân tôm')
# 2018-01-31 17:14:11,482 INFO sqlalchemy.engine.base.Engine COMMIT
# 2018-01-31 17:14:11,483 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2018-01-31 17:14:11,484 INFO sqlalchemy.engine.base.Engine INSERT INTO menus (category, title, image, link, price, n_gram_search_text) VALUES (?, ?, ?, ?, ?, ?)
# 2018-01-31 17:14:11,485 INFO sqlalchemy.engine.base.Engine ('món chính', 'Bánh cuốn chả quế', 'http://quananngon.com.vn/mediacenter/media/images/1428/products/1428/1406/s330_330/banh-cuon-cha-que-quan-an-ngon-1498458686.jpg', 'http://quananngon.com.vn/banh-cuon-cha-que-pd61223.html', 55000.0, 'món chính Bánh_cuốn chả_quế')
# 2018-01-31 17:14:11,486 INFO sqlalchemy.engine.base.Engine COMMIT
# 2018-01-31 17:14:11,489 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2018-01-31 17:14:11,492 INFO sqlalchemy.engine.base.Engine INSERT INTO menus (category, title, image, link, price, n_gram_search_text) VALUES (?, ?, ?, ?, ?, ?)
# 2018-01-31 17:14:11,496 INFO sqlalchemy.engine.base.Engine ('món chính', 'Bún măng gà', 'http://quananngon.com.vn/mediacenter/media/images/1428/products/1428/1406/s330_330/bun-mang-ga-quan-an-ngon-1498462230.jpg', 'http://quananngon.com.vn/bun-mang-ga-pd61228.html', 55000.0, 'món chính Bún măng gà')
# 2018-01-31 17:14:11,497 INFO sqlalchemy.engine.base.Engine COMMIT
# 2018-01-31 17:14:11,499 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2018-01-31 17:14:11,500 INFO sqlalchemy.engine.base.Engine INSERT INTO menus (category, title, image, link, price, n_gram_search_text) VALUES (?, ?, ?, ?, ?, ?)
# 2018-01-31 17:14:11,501 INFO sqlalchemy.engine.base.Engine ('món chính', 'Bánh cuốn Phủ Lý', 'http://quananngon.com.vn/mediacenter/media/images/products/1428/1406/s330_330/banh-cuon-phu-ly-copy-1496717440.jpg', 'http://quananngon.com.vn/banh-cuon-phu-ly-pd61222.html', 65000.0, 'món chính Bánh_cuốn Phủ_Lý')
# 2018-01-31 17:14:11,502 INFO sqlalchemy.engine.base.Engine COMMIT
# 2018-01-31 17:14:11,505 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2018-01-31 17:14:11,506 INFO sqlalchemy.engine.base.Engine INSERT INTO menus (category, title, image, link, price, n_gram_search_text) VALUES (?, ?, ?, ?, ?, ?)
# 2018-01-31 17:14:11,507 INFO sqlalchemy.engine.base.Engine ('món chính', 'Miến măng gà', 'http://quananngon.com.vn/mediacenter/media/images/products/1428/1406/s330_330/mien-mang-ga-1496717069.jpg', 'http://quananngon.com.vn/mien-mang-ga-pd61227.html', 58000.0, 'món chính Miến măng gà')
# 2018-01-31 17:14:11,508 INFO sqlalchemy.engine.base.Engine COMMIT
# 2018-01-31 17:14:11,510 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2018-01-31 17:14:11,511 INFO sqlalchemy.engine.base.Engine INSERT INTO menus (category, title, image, link, price, n_gram_search_text) VALUES (?, ?, ?, ?, ?, ?)
# 2018-01-31 17:14:11,512 INFO sqlalchemy.engine.base.Engine ('món chính', 'Bún bò Huế', 'http://quananngon.com.vn/mediacenter/media/images/products/1428/1406/s330_330/bun-bo-hue-27-1496718176.jpg', 'http://quananngon.com.vn/bun-bo-hue-pd61208.html', 60000.0, 'món chính Bún_bò Huế')
# 2018-01-31 17:14:11,513 INFO sqlalchemy.engine.base.Engine COMMIT
# 2018-01-31 17:14:11,515 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2018-01-31 17:14:11,516 INFO sqlalchemy.engine.base.Engine INSERT INTO menus (category, title, image, link, price, n_gram_search_text) VALUES (?, ?, ?, ?, ?, ?)
# 2018-01-31 17:14:11,518 INFO sqlalchemy.engine.base.Engine ('món chính', 'Hủ tiếu nam vang', 'http://quananngon.com.vn/mediacenter/media/images/1428/products/1428/1406/s330_330/hu-tieu-nam-vang-2-1501063325.jpg', 'http://quananngon.com.vn/hu-tieu-nam-vang-pd61229.html', 60000.0, 'món chính Hủ_tiếu nam_vang')
# 2018-01-31 17:14:11,519 INFO sqlalchemy.engine.base.Engine COMMIT
# 2018-01-31 17:14:11,521 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2018-01-31 17:14:11,522 INFO sqlalchemy.engine.base.Engine INSERT INTO menus (category, title, image, link, price, n_gram_search_text) VALUES (?, ?, ?, ?, ?, ?)
# 2018-01-31 17:14:11,523 INFO sqlalchemy.engine.base.Engine ('món chính', 'Cơm cháy Hải Sản', 'http://quananngon.com.vn/mediacenter/media/images/products/1428/1406/s330_330/com-chay-hai-san-4-1496718511.jpg', 'http://quananngon.com.vn/com-chay-hai-san-pd61202.html', 140000.0, 'món chính Cơm cháy Hải_Sản')
# 2018-01-31 17:14:11,524 INFO sqlalchemy.engine.base.Engine COMMIT
# 2018-01-31 17:14:11,526 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2018-01-31 17:14:11,527 INFO sqlalchemy.engine.base.Engine INSERT INTO menus (category, title, image, link, price, n_gram_search_text) VALUES (?, ?, ?, ?, ?, ?)
# 2018-01-31 17:14:11,528 INFO sqlalchemy.engine.base.Engine ('món chính', 'Cơm hến trộn', 'http://quananngon.com.vn/mediacenter/media/images/1428/products/1428/1406/s330_330/com-hen-tron-quan-an-ngon-1498547530.jpg', 'http://quananngon.com.vn/com-hen-tron-pd61210.html', 60000.0, 'món chính Cơm hến trộn')
# 2018-01-31 17:14:11,530 INFO sqlalchemy.engine.base.Engine COMMIT
# 2018-01-31 17:14:11,531 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2018-01-31 17:14:11,532 INFO sqlalchemy.engine.base.Engine INSERT INTO menus (category, title, image, link, price, n_gram_search_text) VALUES (?, ?, ?, ?, ?, ?)
# 2018-01-31 17:14:11,533 INFO sqlalchemy.engine.base.Engine ('món chính', 'Bánh bèo chén', 'http://quananngon.com.vn/mediacenter/media/images/products/1428/1406/s330_330/banh-beo-chen-1496718404.jpg', 'http://quananngon.com.vn/banh-beo-chen-pd61204.html', 60000.0, 'món chính Bánh_bèo chén')
# 2018-01-31 17:14:11,535 INFO sqlalchemy.engine.base.Engine COMMIT
# 2018-01-31 17:14:11,536 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2018-01-31 17:14:11,537 INFO sqlalchemy.engine.base.Engine INSERT INTO menus (category, title, image, link, price, n_gram_search_text) VALUES (?, ?, ?, ?, ?, ?)
# 2018-01-31 17:14:11,539 INFO sqlalchemy.engine.base.Engine ('món chính', 'Bún măng sườn mọc', 'http://quananngon.com.vn/mediacenter/media/images/products/1428/1406/s330_330/bun-mang-suon-moc-dry-bamboo-noodle-soup-with-pork-ribs--pork-balls-1496718557.jpg', 'http://quananngon.com.vn/bun-mang-suon-moc-pd61201.html', 55000.0, 'món chính Bún măng sườn mọc')
# 2018-01-31 17:14:11,540 INFO sqlalchemy.engine.base.Engine COMMIT
# 2018-01-31 17:14:11,541 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2018-01-31 17:14:11,542 INFO sqlalchemy.engine.base.Engine INSERT INTO menus (category, title, image, link, price, n_gram_search_text) VALUES (?, ?, ?, ?, ?, ?)
# 2018-01-31 17:14:11,543 INFO sqlalchemy.engine.base.Engine ('món chính', 'Bánh gối', 'http://quananngon.com.vn/mediacenter/media/images/products/1428/1406/s330_330/banh-goi-1496718435.jpg', 'http://quananngon.com.vn/banh-goi-pd61203.html', 58000.0, 'món chính Bánh_gối')
# 2018-01-31 17:14:11,544 INFO sqlalchemy.engine.base.Engine COMMIT
# 2018-01-31 17:14:11,546 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2018-01-31 17:14:11,547 INFO sqlalchemy.engine.base.Engine INSERT INTO menus (category, title, image, link, price, n_gram_search_text) VALUES (?, ?, ?, ?, ?, ?)
# 2018-01-31 17:14:11,548 INFO sqlalchemy.engine.base.Engine ('món chính', 'Bánh ít trần', 'http://quananngon.com.vn/mediacenter/media/images/1428/products/1428/1406/s330_330/banh-it-tran-quan-an-ngon-1498459196.jpg', 'http://quananngon.com.vn/banh-it-tran-pd61207.html', 60000.0, 'món chính Bánh_ít trần')
# 2018-01-31 17:14:11,549 INFO sqlalchemy.engine.base.Engine COMMIT
# 2018-01-31 17:14:11,551 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2018-01-31 17:14:11,552 INFO sqlalchemy.engine.base.Engine INSERT INTO menus (category, title, image, link, price, n_gram_search_text) VALUES (?, ?, ?, ?, ?, ?)
# 2018-01-31 17:14:11,552 INFO sqlalchemy.engine.base.Engine ('món chính', 'Bún thang Hà Nội', 'http://quananngon.com.vn/mediacenter/media/images/1428/products/1428/1406/s330_330/bun-thang-quan-an-ngon-1501062711.jpg', 'http://quananngon.com.vn/bun-thang-ha-noi-pd60694.html', 60000.0, 'món chính Bún_thang Hà_Nội')
# 2018-01-31 17:14:11,554 INFO sqlalchemy.engine.base.Engine COMMIT
# 2018-01-31 17:14:11,555 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2018-01-31 17:14:11,556 INFO sqlalchemy.engine.base.Engine INSERT INTO menus (category, title, image, link, price, n_gram_search_text) VALUES (?, ?, ?, ?, ?, ?)
# 2018-01-31 17:14:11,557 INFO sqlalchemy.engine.base.Engine ('món chính', 'Bánh bột lọc Huế', 'http://quananngon.com.vn/mediacenter/media/images/1428/products/1428/1406/s330_330/banh-bot-loc-hue-quan-an-ngon-1498458526.jpg', 'http://quananngon.com.vn/banh-bot-loc-hue-pd61205.html', 60000.0, 'món chính Bánh_bột lọc Huế')
# 2018-01-31 17:14:11,558 INFO sqlalchemy.engine.base.Engine COMMIT
# 2018-01-31 17:14:11,559 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2018-01-31 17:14:11,560 INFO sqlalchemy.engine.base.Engine INSERT INTO menus (category, title, image, link, price, n_gram_search_text) VALUES (?, ?, ?, ?, ?, ?)
# 2018-01-31 17:14:11,561 INFO sqlalchemy.engine.base.Engine ('món chính', 'Bún đậu rán mắm tôm', 'http://quananngon.com.vn/mediacenter/media/images/1428/products/1428/1406/s330_330/bun-dau-mam-tom-1501062578.jpg', 'http://quananngon.com.vn/bun-dau-ran-mam-tom-pd61198.html', 50000.0, 'món chính Bún đậu rán mắm_tôm')
# 2018-01-31 17:14:11,562 INFO sqlalchemy.engine.base.Engine COMMIT
# 2018-01-31 17:14:11,564 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2018-01-31 17:14:11,565 INFO sqlalchemy.engine.base.Engine INSERT INTO menus (category, title, image, link, price, n_gram_search_text) VALUES (?, ?, ?, ?, ?, ?)
# 2018-01-31 17:14:11,566 INFO sqlalchemy.engine.base.Engine ('món chính', 'Bánh bột lọc Hà Nội', 'http://quananngon.com.vn/mediacenter/media/images/1428/products/1428/1406/s330_330/banh-bot-loc-ha-noi-quan-an-ngon-1498458450.jpg', 'http://quananngon.com.vn/banh-bot-loc-ha-noi-pd61206.html', 60000.0, 'món chính Bánh_bột lọc Hà_Nội')
# 2018-01-31 17:14:11,567 INFO sqlalchemy.engine.base.Engine COMMIT
# 2018-01-31 17:14:11,569 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2018-01-31 17:14:11,570 INFO sqlalchemy.engine.base.Engine INSERT INTO menus (category, title, image, link, price, n_gram_search_text) VALUES (?, ?, ?, ?, ?, ?)
# 2018-01-31 17:14:11,571 INFO sqlalchemy.engine.base.Engine ('món chính', 'Bánh canh cua', 'http://quananngon.com.vn/mediacenter/media/images/1428/products/1428/1406/s330_330/banh-canh-cua-quan-an-ngon-1498458607.jpg', 'http://quananngon.com.vn/banh-canh-cua-pd61200.html', 65000.0, 'món chính Bánh_canh cua')
# 2018-01-31 17:14:11,573 INFO sqlalchemy.engine.base.Engine COMMIT
# 2018-01-31 17:14:11,576 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2018-01-31 17:14:11,578 INFO sqlalchemy.engine.base.Engine INSERT INTO menus (category, title, image, link, price, n_gram_search_text) VALUES (?, ?, ?, ?, ?, ?)
# 2018-01-31 17:14:11,579 INFO sqlalchemy.engine.base.Engine ('món chính', 'Cơm gà hội an', 'http://quananngon.com.vn/mediacenter/media/images/1428/products/1428/1406/s330_330/com-ga-hoi-an-quan-an-ngon-1498466081.jpg', 'http://quananngon.com.vn/com-ga-hoi-an-pd60693.html', 175000.0, 'món chính Cơm gà hội an')
# 2018-01-31 17:14:11,580 INFO sqlalchemy.engine.base.Engine COMMIT

# %%
session.query(Menu).get(1)
# Out:
# 2018-01-31 17:14:17,028 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2018-01-31 17:14:17,029 INFO sqlalchemy.engine.base.Engine SELECT menus.id AS menus_id, menus.category AS menus_category, menus.title AS menus_title, menus.image AS menus_image, menus.link AS menus_link, menus.price AS menus_price, menus.n_gram_search_text AS menus_n_gram_search_text
# FROM menus
# WHERE menus.id = ?
# 2018-01-31 17:14:17,030 INFO sqlalchemy.engine.base.Engine (1,)
# <Menu(category='tráng miệng', title='Tào phớ', price='20.000₫')>
